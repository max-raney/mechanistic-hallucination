# %% [markdown]
# <a href="https://colab.research.google.com/github/max-raney/mechanistic-hallucination/blob/main/CS182_Proj_runmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Successfully uninstalled torchvision-0.21.0+cu124
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 97.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 43.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 99.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 7.0 MB/s eta 0:00:00
# ...

# %%
# !pip install -U transformers accelerate

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# !git clone https://github.com/max-raney/mechanistic-hallucination.git
# %cd mechanistic-hallucination
# Out:
# Cloning into 'mechanistic-hallucination'...
# remote: Enumerating objects: 185, done.
# remote: Counting objects: 100% (185/185), done.
# remote: Compressing objects: 100% (168/168), done.
# remote: Total 185 (delta 69), reused 52 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (185/185), 145.30 KiB | 13.21 MiB/s, done.
# Resolving deltas: 100% (69/69), done.
# /content/mechanistic-hallucination

# %%
# !pip install transformers huggingface_hub torch tqdm matplotlib

# %%
# !python src/mechanistic_interventions/sandboxs/download_models.py
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# model-00003-of-00004.safetensors:  23% 1.12G/4.92G [00:34<01:30, 42.0MB/s]
#
#
#
# model-00004-of-00004.safetensors:  96% 1.12G/1.17G [00:34<00:01, 42.1MB/s]
#
# model-00001-of-00004.safetensors:  24% 1.21G/4.98G [00:34<01:19, 47.3MB/s]
#
#
#
#
# consolidated.00.pth:   7% 1.11G/16.1G [00:34<05:04, 49.1MB/s]
# model-00002-of-00004.safetensors:  24% 1.20G/5.00G [00:34<01:44, 36.5MB/s]
#
#
#
# model-00004-of-00004.safetensors:  97% 1.13G/1.17G [00:34<00:00, 48.2MB/s]
#
#
# model-00003-of-00004.safetensors:  23% 1.13G/4.92G [00:34<01:20, 47.0MB/s]
#
# model-00001-of-00004.safetensors:  24% 1.22G/4.98G [00:34<01:09, 54.0MB/s]
# model-00002-of-00004.safetensors:  24% 1.21G/5.00G [00:35<01:24, 45.1MB/s]
#
#
#
#
# consolidated.00.pth:   7% 1.12G/16.1G [00:34<04:41, 53.0MB/s]
#
# model-00001-of-00004.safetensors:  25% 1.23G/4.98G [00:35<01:02, 60.2MB/s]
#
#
#
# model-00004-of-00004.safetensors:  98% 1.14G/1.17G [00:34<00:00, 51.2MB/s]
# ...

# %%
# !python src/mechanistic_interventions/sandboxs/sandbox_gemma.py
# Out:
# Loading Gemma from /content/models/google_gemma-2b ...
# 2025-05-04 03:41:30.976632: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746330091.270369    4151 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746330091.352385    4151 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-04 03:41:32.025261: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# !python train_concept_vectors.py
# Out:
# Analysis：
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91         6
#            1       1.00      1.00      1.00         4
#            2       0.83      1.00      0.91         5
#            3       1.00      1.00      1.00         7
#
#     accuracy                           0.95        22
#    macro avg       0.96      0.96      0.95        22
# weighted avg       0.96      0.95      0.95        22
#
# Saved as gemma_concept_vector_clf.pkl

# %%
# !python mean_diff.py --class hallucination --layer 16
# Out:
# Mean-diff vector saved to: concept_vectors/hallucination_mean_diff.pt

# %%
# !python inference_with_intervention.py \
    --prompt "List alien universities." \
    --target_direction concept_vectors/hallucination_mean_diff.pt \
    --alpha 5.0 \
    --layer 16 \
    --mode suppress
# Out:
# 2025-05-04 04:25:39.525539: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746332739.559809   15089 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746332739.570349   15089 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-04 04:25:39.605894: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
