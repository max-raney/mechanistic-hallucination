# %% [markdown]
# <a href="https://colab.research.google.com/github/max-raney/mechanistic-hallucination/blob/main/CS182_Proj_gemmamodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Successfully uninstalled torchvision-0.21.0+cu124
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 103.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 57.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 127.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 14.4 MB/s eta 0:00:00
# ...

# %%
# !pip install -U transformers accelerate

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA A100-SXM4-40GB

# %%
# !git clone https://github.com/max-raney/mechanistic-hallucination.git
# %cd mechanistic-hallucination
# Out:
# Cloning into 'mechanistic-hallucination'...
# remote: Enumerating objects: 256, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 256 (delta 0), reused 0 (delta 0), pack-reused 255 (from 1)
# Receiving objects: 100% (256/256), 193.54 KiB | 3.72 MiB/s, done.
# Resolving deltas: 100% (105/105), done.
# /content/mechanistic-hallucination

# %%
# !pip install transformers huggingface_hub torch tqdm matplotlib

# %%
# !python src/mechanistic_interventions/sandboxs/download_models.py
# Out:
# Streaming output truncated to the last 5000 lines.
# model-00001-of-00004.safetensors:  47% 2.34G/4.98G [00:45<00:31, 83.7MB/s]
#
# model-00002-of-00004.safetensors:  42% 2.11G/5.00G [00:45<00:35, 80.6MB/s]
#
#
# model-00003-of-00004.safetensors:  48% 2.36G/4.92G [00:45<00:30, 83.0MB/s]
#
#
#
#
# consolidated.00.pth:  12% 1.90G/16.1G [00:44<02:55, 80.9MB/s]
# model-00001-of-00004.safetensors:  47% 2.35G/4.98G [00:45<00:32, 80.0MB/s]
#
# model-00002-of-00004.safetensors:  42% 2.12G/5.00G [00:45<00:35, 81.5MB/s]
#
#
#
#
# consolidated.00.pth:  12% 1.91G/16.1G [00:45<02:53, 81.6MB/s]
#
#
# model-00003-of-00004.safetensors:  48% 2.37G/4.92G [00:45<00:32, 79.5MB/s]
# model-00001-of-00004.safetensors:  47% 2.36G/4.98G [00:45<00:32, 80.7MB/s]
#
# model-00002-of-00004.safetensors:  43% 2.13G/5.00G [00:45<00:36, 78.0MB/s]
#
#
#
#
# consolidated.00.pth:  12% 1.92G/16.1G [00:45<03:01, 78.0MB/s]
#
#
# model-00003-of-00004.safetensors:  48% 2.38G/4.92G [00:45<00:32, 78.2MB/s]
# ...

# %%
# !python src/mechanistic_interventions/sandboxs/sandbox_gemma.py
# Out:
# Loading Gemma from /content/models/google_gemma-2b ...
# 2025-05-05 00:08:27.858434: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-05 00:08:28.515148: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746403708.716916    6172 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python src/mechanistic_interventions/scripts/train_concept_vectors.py
# Out:
# Analysis：
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91         6
#            1       1.00      1.00      1.00         4
#            2       0.83      1.00      0.91         5
#            3       1.00      1.00      1.00         7
#
#     accuracy                           0.95        22
#    macro avg       0.96      0.96      0.95        22
# weighted avg       0.96      0.95      0.95        22
#
# Saved as gemma_concept_vector_clf.pkl

# %%
# !python src/mechanistic_interventions/scripts/gemma_batch_intervention.py
# Out:
# 2025-05-05 00:19:16.242684: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-05 00:19:16.261999: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746404356.284027    9106 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746404356.290700    9106 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python results/visualization.py
# Out:
# Figure(640x480)
# LaTeX table ↓
#
# \begin{tabular}{lrrrr}
# \toprule
# mode & alpha & base_rate & after_rate & delta \\
# \midrule
# enhance & 5 & 0.065 & 0.065 & 0.000 \\
# enhance & 10 & 0.065 & 0.065 & 0.000 \\
# enhance & 20 & 0.065 & 0.065 & 0.000 \\
# suppress & 5 & 0.065 & 0.065 & 0.000 \\
# suppress & 10 & 0.065 & 0.056 & -0.009 \\
# suppress & 20 & 0.065 & 0.056 & -0.009 \\
# \bottomrule
# \end{tabular}
